# %% [markdown]
# # Local AML TF Model Deployment

# %%
# Creating a local endpoint
import datetime
# import required libraries
from azure.ai.ml import MLClient
from azure.ai.ml.entities import (
    ManagedOnlineEndpoint,
    ManagedOnlineDeployment,
    Model,
    Environment,
    CodeConfiguration,
)
from azure.identity import DefaultAzureCredential

# enter details of your AzureML workspace
subscription_id = "6187b663-b744-4d24-8226-7e66525baf8f"
resource_group = "abir-rg"
workspace = "abir-reco"

# get a handle to the workspace
ml_client = MLClient(
    DefaultAzureCredential(), subscription_id, resource_group, workspace
)
local_endpoint_name = "local-" + datetime.datetime.now().strftime("%m%d%H%M%f")
# create an online endpoint
endpoint = ManagedOnlineEndpoint(
    name=local_endpoint_name, description="this is a sample local endpoint"
)

# %%
ml_client.online_endpoints.begin_create_or_update(endpoint, local=True)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# /anaconda/envs/py37_tensorflow/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     709                 headers=headers,
# --> 710                 chunked=chunked,
#     711             )
#
# /anaconda/envs/py37_tensorflow/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     397             else:
# --> 398                 conn.request(method, url, **httplib_request_kw)
#     399
#
# /anaconda/envs/py37_tensorflow/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1251         """Send a complete request to the server."""
# -> 1252         self._send_request(method, url, body, headers, encode_chunked)
#    1253
#
# /anaconda/envs/py37_tensorflow/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1297             body = _encode(body, 'body')
# -> 1298         self.endheaders(body, encode_chunked=encode_chunked)
#    1299
#
# /anaconda/envs/py37_tensorflow/lib/python3.7/http/client.py in endheaders(self, message_body, encode_chunked)
#    1246             raise CannotSendHeader()
# -> 1247         self._send_output(message_body, encode_chunked=encode_chunked)
#    1248
#
# /anaconda/envs/py37_tensorflow/lib/python3.7/http/client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# /anaconda/envs/py37_tensorflow/lib/python3.7/http/client.py in send(self, data)
#     965             if self.auto_open:
# --> 966                 self.connect()
#     967             else:
#
# /anaconda/envs/py37_tensorflow/lib/python3.7/site-packages/docker/transport/unixconn.py in connect(self)
#      29         sock.settimeout(self.timeout)
# ---> 30         sock.connect(self.unix_socket)
#      31         self.sock = sock
#
# PermissionError: [Errno 13] Permission denied
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# /anaconda/envs/py37_tensorflow/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# /anaconda/envs/py37_tensorflow/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     787             retries = retries.increment(
# --> 788                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     789             )
#
# /anaconda/envs/py37_tensorflow/lib/python3.7/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     549             if read is False or not self._is_method_retryable(method):
# --> 550                 raise six.reraise(type(error), error, _stacktrace)
#     551             elif read is not None:
#
# /anaconda/envs/py37_tensorflow/lib/python3.7/site-packages/urllib3/packages/six.py in reraise(tp, value, tb)
#     768             if value.__traceback__ is not tb:
# --> 769                 raise value.with_traceback(tb)
#     770             raise value
#
# /anaconda/envs/py37_tensorflow/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     709                 headers=headers,
# --> 710                 chunked=chunked,
#     711             )
#
# /anaconda/envs/py37_tensorflow/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     397             else:
# --> 398                 conn.request(method, url, **httplib_request_kw)
#     399
#
# /anaconda/envs/py37_tensorflow/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1251         """Send a complete request to the server."""
# -> 1252         self._send_request(method, url, body, headers, encode_chunked)
#    1253
#
# /anaconda/envs/py37_tensorflow/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1297             body = _encode(body, 'body')
# -> 1298         self.endheaders(body, encode_chunked=encode_chunked)
#    1299
#
# /anaconda/envs/py37_tensorflow/lib/python3.7/http/client.py in endheaders(self, message_body, encode_chunked)
#    1246             raise CannotSendHeader()
# -> 1247         self._send_output(message_body, encode_chunked=encode_chunked)
#    1248
#
# /anaconda/envs/py37_tensorflow/lib/python3.7/http/client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# /anaconda/envs/py37_tensorflow/lib/python3.7/http/client.py in send(self, data)
#     965             if self.auto_open:
# --> 966                 self.connect()
#     967             else:
#
# /anaconda/envs/py37_tensorflow/lib/python3.7/site-packages/docker/transport/unixconn.py in connect(self)
#      29         sock.settimeout(self.timeout)
# ---> 30         sock.connect(self.unix_socket)
#      31         self.sock = sock
#
# ProtocolError: ('Connection aborted.', PermissionError(13, 'Permission denied'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# /anaconda/envs/py37_tensorflow/lib/python3.7/site-packages/docker/api/client.py in _retrieve_server_version(self)
#     213         try:
# --> 214             return self.version(api_version=False)["ApiVersion"]
#     215         except KeyError:
#
# /anaconda/envs/py37_tensorflow/lib/python3.7/site-packages/docker/api/daemon.py in version(self, api_version)
#     180         url = self._url("/version", versioned_api=api_version)
# --> 181         return self._result(self._get(url), json=True)
#
# /anaconda/envs/py37_tensorflow/lib/python3.7/site-packages/docker/utils/decorators.py in inner(self, *args, **kwargs)
#      45                 kwargs['headers'].update(self._general_configs['HttpHeaders'])
# ---> 46         return f(self, *args, **kwargs)
#      47     return inner
#
# /anaconda/envs/py37_tensorflow/lib/python3.7/site-packages/docker/api/client.py in _get(self, url, **kwargs)
#     236     def _get(self, url, **kwargs):
# --> 237         return self.get(url, **self._set_request_timeout(kwargs))
#     238
#
# /anaconda/envs/py37_tensorflow/lib/python3.7/site-packages/requests/sessions.py in get(self, url, **kwargs)
#     554         kwargs.setdefault('allow_redirects', True)
# --> 555         return self.request('GET', url, **kwargs)
#     556
#
# /anaconda/envs/py37_tensorflow/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#
# /anaconda/envs/py37_tensorflow/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#
# /anaconda/envs/py37_tensorflow/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     497         except (ProtocolError, socket.error) as err:
# --> 498             raise ConnectionError(err, request=request)
#     499
#
# ConnectionError: ('Connection aborted.', PermissionError(13, 'Permission denied'))
#
# During handling of the above exception, another exception occurred:
#
# DockerException                           Traceback (most recent call last)
# /anaconda/envs/py37_tensorflow/lib/python3.7/site-packages/azure/ai/ml/_local_endpoints/docker_client.py in _client(self)
#      61             try:
# ---> 62                 self._lazy_client = docker.from_env()
#      63             except DockerException as e:
#
# /anaconda/envs/py37_tensorflow/lib/python3.7/site-packages/docker/client.py in from_env(cls, **kwargs)
#     100             use_ssh_client=use_ssh_client,
# --> 101             **kwargs_from_env(**kwargs)
#     102         )
#
# /anaconda/envs/py37_tensorflow/lib/python3.7/site-packages/docker/client.py in __init__(self, *args, **kwargs)
#      44     def __init__(self, *args, **kwargs):
# ---> 45         self.api = APIClient(*args, **kwargs)
#      46
#
# /anaconda/envs/py37_tensorflow/lib/python3.7/site-packages/docker/api/client.py in __init__(self, base_url, version, timeout, tls, user_agent, num_pools, credstore_env, use_ssh_client, max_pool_size)
#     196                                 ) and version.lower() == 'auto'):
# --> 197             self._version = self._retrieve_server_version()
#     198         else:
#
# /anaconda/envs/py37_tensorflow/lib/python3.7/site-packages/docker/api/client.py in _retrieve_server_version(self)
#     221             raise DockerException(
# --> 222                 f'Error while fetching server API version: {e}'
#     223             )
#
# DockerException: Error while fetching server API version: ('Connection aborted.', PermissionError(13, 'Permission denied'))
#
# During handling of the above exception, another exception occurred:
#
# DockerEngineNotAvailableError             Traceback (most recent call last)
# <ipython-input-5-96d7b964c38b> in <module>
# ----> 1 ml_client.online_endpoints.begin_create_or_update(endpoint, local=True)
#
# /anaconda/envs/py37_tensorflow/lib/python3.7/site-packages/azure/ai/ml/_telemetry/activity.py in wrapper(*args, **kwargs)
#     256         def wrapper(*args, **kwargs):
#     257             with log_activity(logger, activity_name or f.__name__, activity_type, custom_dimensions):
# --> 258                 return f(*args, **kwargs)
#     259
#     260         return wrapper
#
# /anaconda/envs/py37_tensorflow/lib/python3.7/site-packages/azure/ai/ml/operations/_online_endpoint_operations.py in begin_create_or_update(self, endpoint, local, **kwargs)
#     196         """
#     197         if local:
# --> 198             return self._local_endpoint_helper.create_or_update(endpoint=endpoint)
#     199
#     200         no_wait = kwargs.get("no_wait", False)
#
# /anaconda/envs/py37_tensorflow/lib/python3.7/site-packages/azure/ai/ml/operations/_local_endpoint_helper.py in create_or_update(self, endpoint)
#      45
#      46         try:
# ---> 47             self.get(endpoint_name=endpoint.name)
#      48             operation_message = "Updating local endpoint"
#      49         except LocalEndpointNotFoundError:
#
# /anaconda/envs/py37_tensorflow/lib/python3.7/site-packages/azure/ai/ml/operations/_local_endpoint_helper.py in get(self, endpoint_name)
#      88         """
#      89         endpoint = self._endpoint_stub.get(endpoint_name=endpoint_name)
# ---> 90         container = self._docker_client.get_endpoint_container(endpoint_name=endpoint_name, include_stopped=True)
#      91         if endpoint:
#      92             if container:
#
# /anaconda/envs/py37_tensorflow/lib/python3.7/site-packages/azure/ai/ml/_local_endpoints/docker_client.py in get_endpoint_container(self, endpoint_name, deployment_name, verify_single_deployment, include_stopped)
#     377             endpoint_name=endpoint_name,
#     378             deployment_name=deployment_name,
# --> 379             include_stopped=include_stopped,
#     380         )
#     381         if len(containers) == 0:
#
# /anaconda/envs/py37_tensorflow/lib/python3.7/site-packages/azure/ai/ml/_local_endpoints/docker_client.py in list_containers(self, endpoint_name, deployment_name, include_stopped)
#     337             filters["label"].append(f"{LocalEndpointConstants.LABEL_KEY_DEPLOYMENT_NAME}={deployment_name}")
#     338
# --> 339         return self._client.containers.list(filters=filters, all=include_stopped)
#     340
#     341     def get_container_labels(
#
# /anaconda/envs/py37_tensorflow/lib/python3.7/site-packages/azure/ai/ml/_local_endpoints/docker_client.py in _client(self)
#      63             except DockerException as e:
#      64                 if "Error while fetching server API version" in str(e):
# ---> 65                     raise DockerEngineNotAvailableError()
#      66                 raise
#      67         return self._lazy_client
#
# DockerEngineNotAvailableError: Please make sure Docker Engine is installed and running. https://docs.docker.com/engine/install/
